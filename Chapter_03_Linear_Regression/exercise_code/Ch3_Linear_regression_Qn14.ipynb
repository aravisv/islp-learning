# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence \
     import variance_inflation_factor as VIF

# %%
rng = np.random. default_rng (10)
x1 = rng.uniform (0, 1, size =100)
x2 = 0.5 * x1 + rng.normal(size =100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size =100)

# %%
"""
x1 coefficient = 2
x2 coefficient = 0.3 * 0.5 = 0.15
"""
# Out:
# '\nx1 coefficient = 2\nx2 coefficient = 0.3 * 0.5 = 0.15\n'

# %%
df1 = pd.DataFrame({'x1':x1, 'x2':x2})

# %%
df1.corr()
# Out:
#           x1        x2
# x1  1.000000  0.772324
# x2  0.772324  1.000000

# %%
ax = plt.subplots(figsize = (8,8))[1]
ax.scatter(x1,x2)

# %%
df1 = sm.add_constant(df1)
model1 = sm.OLS(y, df1)
result1 = model1.fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     19.89
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           5.76e-08
# Time:                        20:22:53   Log-Likelihood:                -130.62
# No. Observations:                 100   AIC:                             267.2
# Df Residuals:                      97   BIC:                             275.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9579      0.190     10.319      0.000       1.581       2.334
# ...

# %%
"""
const is almost same to the original b0
coefficients vary by almost 0.5
b2 (coefficient of x2) has high p value. reject the hypothesis that it has any effect
"""
# Out:
# '\nconst is almost same to the original b0\ncoefficients vary by almost 0.5\nb2 (coefficient of x2) has high p value. reject the hypothesis that it has any effect\n'

# %%
model2 = sm.OLS(y, df1.drop(columns = ['x2']))
result2 = model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     38.39
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           1.37e-08
# Time:                        20:22:53   Log-Likelihood:                -131.28
# No. Observations:                 100   AIC:                             266.6
# Df Residuals:                      98   BIC:                             271.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9371      0.189     10.242      0.000       1.562       2.312
# ...

# %%
"""
the coefficient of x1 cant be rejected as the p value is less
"""
# Out:
# '\nthe coefficient of x1 cant be rejected as the p value is less\n'

# %%
model3 = sm.OLS(y, df1.drop(columns = ['x1']))
result3 = model3.fit()
result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     27.99
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           7.43e-07
# Time:                        20:22:53   Log-Likelihood:                -135.24
# No. Observations:                 100   AIC:                             274.5
# Df Residuals:                      98   BIC:                             279.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3239      0.154     15.124      0.000       2.019       2.629
# ...

# %%
"""
the coefficient of x2 cant be rejected as the p value is less
when the model if fit individually, the coefficients change and there is no enough evidence to accept the null hypothesis
"""
# Out:
# '\nthe coefficient of x2 cant be rejected as the p value is less\nwhen the model if fit individually, the coefficients change and there is no enough evidence to accept the null hypothesis\n'

# %%
x1 = np. concatenate ([x1 , [0.1]])
x2 = np. concatenate ([x2 , [0.8]])
y = np. concatenate ([y, [6]])

# %%
df2 = pd.DataFrame({'x1':x1, 'x2':x2})
df2 = sm.add_constant(df2)

# %%
model4 = sm.OLS(y, df2)
result4 = model4.fit()
result4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     20.17
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           4.60e-08
# Time:                        20:22:53   Log-Likelihood:                -135.30
# No. Observations:                 101   AIC:                             276.6
# Df Residuals:                      98   BIC:                             284.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0618      0.192     10.720      0.000       1.680       2.443
# ...

# %%
model5 = sm.OLS(y, df2.drop(columns = ['x2']))
result5 = model5.fit()
result5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           9.23e-07
# Time:                        20:22:53   Log-Likelihood:                -140.37
# No. Observations:                 101   AIC:                             284.7
# Df Residuals:                      99   BIC:                             290.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0739      0.201     10.310      0.000       1.675       2.473
# ...

# %%
model6 = sm.OLS(y, df2.drop(columns = ['x1']))
result6 = model6.fit()
result6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     36.10
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           3.13e-08
# Time:                        20:22:53   Log-Likelihood:                -137.01
# No. Observations:                 101   AIC:                             278.0
# Df Residuals:                      99   BIC:                             283.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2840      0.151     15.088      0.000       1.984       2.584
# ...

# %%
import matplotlib.pyplot as plt

models = {
    "Model 3": result3,
    "Model 4": result4,
    "Model 5": result5
}

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

for ax, (name, res) in zip(axes, models.items()):
    influence = res.get_influence()
    studentized_residuals = influence.resid_studentized_external
    ax.scatter(res.fittedvalues, studentized_residuals)
    
    ax.axhline(0, linestyle = '--', linewidth = 2)
    ax.axhline(y = 3, color = 'orange', linestyle = ':')  
    ax.axhline(y = -3, color = 'orange', linestyle = ':') 

    mask = np.abs(studentized_residuals) > 3
    ax.scatter(res.fittedvalues[mask], studentized_residuals[mask], color="red", s=80)

    ax.set_title(name)
    ax.set_xlabel("Fitted values")
    ax.set_ylabel("Studentized Residuals")

plt.tight_layout()
plt.show()

# %%
"""
from the above studentized residual plot, there is only one outlier in the model where x2 is omitted
"""
threshold = 3
influence = result5.get_influence()
studentized_residuals = influence.resid_studentized_external
outlier_idx = np.where(np.abs(stud_resid) > threshold)[0]

df2.loc[outlier_idx]
# Out:
#      const   x1   x2
# 100    1.0  0.1  0.8

# %%
"""
the outlier is the one which we added at the end
"""

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

models = {
    "Model 3": result3,
    "Model 4": result4,
    "Model 5": result5
}

for ax, (name, res) in zip(axes, models.items()):
    infl = res.get_influence()
    h = infl.hat_matrix_diag

    ax.scatter(np.arange(len(h)), h)
    ax.set_title(name)
    ax.set_xlabel("Index")
    ax.set_ylabel("Leverage")
    
plt.tight_layout()
plt.show()

# %%
# calculating the high leverage points as per text book definition yields us many indices
infl = result3.get_influence()
h = infl.hat_matrix_diag

p = res.df_model
n = res.nobs
threshold = (p + 1) / n

high_lev_idx = np.where(h > threshold)
high_lev_idx
# Out:
# (array([ 0,  2,  9, 15, 17, 18, 23, 24, 26, 31, 34, 35, 36, 37, 40, 41, 49,
#         51, 52, 53, 61, 64, 65, 66, 70, 72, 74, 78, 83, 84, 89, 92, 96]),)

# %%
# cooks distance above 4 is a good measure to get the influential observations
infl = result3.get_influence()
cooks_d = infl.cooks_distance[0]
influential_idx = np.where(cooks_d > 4 / n)[0]
print("Influential points:", influential_idx)
# Out:
# Influential points: [15 36 52 84]

# %%
infl = result4.get_influence()
cooks_d = infl.cooks_distance[0]
influential_idx = np.where(cooks_d > 4 / n)[0]
print("Influential points:", influential_idx)
# Out:
# Influential points: [ 15  32  36  99 100]

# %%
infl = result5.get_influence()
cooks_d = infl.cooks_distance[0]
influential_idx = np.where(cooks_d > 4 / n)[0]
print("Influential points:", influential_idx)
# Out:
# Influential points: [  5  32  36  52  99 100]
