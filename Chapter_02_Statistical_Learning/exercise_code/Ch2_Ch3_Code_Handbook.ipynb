# %%
# libraries to import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.outliers_influence \
     import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)
import seaborn as sns

# %%
# load data
df = pd.read_csv('pathName/fileName.csv')
# load data and interpret junk strings as NA values
df = pd.read_csv('pathName/fileName.csv', na_values = [list of junk strings])

# %%
# to get the first few records
df.head()
# to get the data info
df.info()
# to get summary on the dataframe's columns' statistic summary
df.describe()

# %%
# check the unique values in particular column
np.unique(df['column_name'])

# %%
# drops the rows with any cell having na value
df = df.dropna()

# %%
# change the numerical datatype to categorical
df.ColName = pd.Series(df.ColName, dtype = 'category')

# %%
# set the index for dataframe
df = df.set_index('column_name')

# %%
# get the row based on the index value
df.loc['index_value']

# %%
# histogram for all the variables
fig, ax = subplots(figsize=(20,20))
df.hist(color='green', bins=12, ax=ax);

# %%
# histogram for specific column
fig, ax = subplots(figsize=(20,20))
df.hist('columnName', color='green', bins=12, ax=ax);

# %%
# scatter matrix
pd.plotting.scatter_matrix(df);

# %%
# boxplot
fig, ax = subplots(figsize=(8,8))
df.boxplot('columnName1', by = 'columnName2', ax = ax);

# %%
# correlation
df.corr()

# %%
# correlation heat map
plt.figure(figsize=(8, 8))
numeric_df = df[[Columns]]
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    vmin=-1,
    vmax=1
)
plt.title('Correlation Heatmap')
plt.show()

# %%
# fit the model without ISLP

X = pd.DataFrame({'x': x})
# adds intercept and returns design matrix
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
model.summary()

# %%
# fit an ordinary least square - linear regression model 
# prepare data using ISLP's ModelSpec library

# drop the outcome column or other columns from the input
predictors = list(df.columns.drop(['outcome']))
y = df['outcome']
final_predictors = predictors
X = MS(final_predictors).fit_transform(df)
model = sm.OLS(y, X)
results = model.fit()
results.summary()

# %%
# fit an ordinary least square - linear regression model 
# using statsmodels formula method

formula = "outcome ~ formula"
model = smf.ols(formula, data = df)
result_formula_api = model.fit()
result_formula_api.summary()

# %%
# use ISLP's summarize method for brief summary
summarize(results)

# %%
# get predictions 
data = {
    'col1': [values],
    'col2': [values]
}
prediction_df = pd.DataFrame(data)
prediction_df = design.transform(prediction_df)

predictions = results.get_prediction(prediction_df);
predictions.predicted_mean

# %%
# confidence interval
predictions.conf_int(alpha=0.05)
# prediction interval 
new_predictions.conf_int(obs=True, alpha=0.05)

# %%
# residual plot
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(results.fittedvalues, results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--');

# %%
# function to draw regression line on the data
def abline(ax, b, m, *args, **kwargs):
    xlim = ax.get_xlim()
    ylim = [ m * xlim[0] + b, m * xlim[1] + b]
    ax.plot(xlim,ylim, *args, **kwargs)

# scatter plot and regression line on the data
ax = df.plot.scatter('input_col', 'output_col')
abline(ax, results.params[0], results.params[1], 'r--', linewidth = 3)

# %%
# Computes influence diagnostics for each observation in your fitted OLS model
infl = results.get_influence()
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')

# identifies index of largest element of an array
highest_influence_observation = np.argmax(infl.hat_matrix_diag)

# %%
# anova - analysis of variance
anova_lm(results, args*)

# the model should have designInfo. for which we need to fit the model via \
# smf.ols(formula, data = df).fit()
